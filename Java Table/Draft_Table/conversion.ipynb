# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load_json = "jayconv.json"

# Read Purchasing File and store into Pandas data frame
df = pd.read_json(file_to_load_json, orient="records")

# %%
df.dtypes
# Out:
# city                       object
# comments                   object
# country                    object
# datetime           datetime64[ns]
# durationMinutes            object
# shape                      object
# state                      object
# dtype: object

# %%
df['datetime'] = df['datetime'].dt.strftime('%m/%d/%Y')

# %%
df['datetime'] = df['datetime'].astype(str)

# %%
df = df[["datetime","city","state", "country", "durationMinutes", "shape", "comments"]]
df
# Out:
#        datetime            city state country            durationMinutes  \
# 0    01/01/2010          benton    ar      us                    5 mins.
# 1    01/01/2010          bonita    ca      us                 13 minutes
# 2    01/01/2010        el cajon    ca      us                  6 minutes
# 3    01/01/2010        el cajon    ca      us                 12 minutes
# 4    01/01/2010          fresno    ca      us                      1 min
# 5    01/01/2010     grants pass    or      us              a few mintues
# 6    01/01/2010         la mesa    ca      us                     10 min
# 7    01/01/2010     lemon grove    ca      us           about 15 minutes
# 8    01/01/2010        maricopa    az      us                  3 minutes
# 9    01/01/2010       park city    ky      us                2-3 seconds
# 10   01/01/2010       st. louis    mo      us                      1 min
# 11   01/01/2010        el cajon    ca      us                    15 min.
# 12   01/01/2010   spring valley    ca      us                      10:00
# 13   01/01/2010          willow    ak      us                      7 min
# 14   01/01/2010         antioch    ca      us                 30 minuets
# 15   01/01/2010        el cajon    ca      us                      10min
# 16   01/01/2010          naples    fl      us                      2 min
# 17   01/01/2010         la mesa    ca      us                4-6 minutes
# 18   01/01/2010       anchorage    ak      us                 one minute
# 19   01/01/2010   national city    ca      us                25 mintutes
# 20   01/01/2010      boca raton    fl      us                  4 minutes
# 21   01/01/2010          falcon    co      us                     8 mins
# 22   01/01/2010       crestview    fl      us                  2 minutes
# 23   01/01/2010           aspen    co      us                     2 mins
# 24   01/01/2010        walworth    wi      us                5-7 minutes
# 25   01/01/2010           baker    fl      us                         15
# 26   01/01/2010       san diego    ca      us                 20 minutes
# 27   01/01/2010          willow    ak      us                  10-11 min
# 28   01/01/2010       san diego    ca      us                  3 minutes
# 29   01/01/2010       haverhill    ma      us                 30 seconds
# ..          ...             ...   ...     ...                        ...
# 796  05/01/2010          naples    fl      us                  5 minutes
# 797  05/01/2010     east boston    ma      us               5-10 minutes
# 798  05/01/2010        tularosa    nm      us                ~30 minutes
# 799  05/01/2010      santa cruz    ca      us                  2 minutes
# 800  05/01/2010      gig harbor    wa      us           approx half hour
# 801  05/01/2010   hallettsville    tx      us                 30 seconds
# 802  05/01/2010         tijeras    nm      us                     5 min.
# 803  05/01/2010  edson (canada)    ab      ca  about 15 minutes each tim
# 804  05/01/2010        richmond    va      us               3-5 minutes.
# 805  05/02/2010     los angeles    ca      us                         30
# 806  05/02/2010            bend    or      us                  2 minutes
# 807  05/02/2010      alpharetta    ga      us             about 1 minute
# 808  05/02/2010        berkeley    ca      us                  5 minutes
# 809  05/02/2010          austin    tx      us                  4 minutes
# 810  05/02/2010   fort atkinson    wi      us                      2 min
# 811  05/02/2010        hometown    il      us                      5 min
# 812  05/02/2010      wilmington    ca      us                 40 seconds
# 813  05/03/2010        savannah    tn      us                 30 seconds
# 814  05/03/2010         whitman    ma      us                  30 second
# 815  05/03/2010         mchenry    il      us                 0ne minute
# 816  05/03/2010         mchenry    il      us                   30 secs.
# 817  05/03/2010      louisville    ky      us                      22:00
# 818  05/03/2010           omaha    ne      us                     4 mins
# 819  05/03/2010       knoxville    tn      us                  3 minutes
# 820  05/03/2010           ukiah    ca      us                    current
# 821  05/03/2010   state college    pa      us                 ~5 minutes
# 822  05/04/2010          pierce    tx      us          1 hour 30 minutes
# 823  05/04/2010      san angelo    tx      us              approx 45 sec
# 824  05/04/2010   santa clarita    ca      us                 12 minutes
# 825  05/04/2010       ewa beach    hi      us                  2 seconds
#
#          shape                                           comments
# 0       circle  4 bright green circles high in the sky going i...
# 1        light  Three bright red lights witnessed floating sta...
# 2     triangle  On New Years Eve I went outside to hear the ce...
# 3     triangle            3 Red objects hovering over El Cajon CA
# 4        light  Fresno cal. bright light hovers over head then...
# 5     triangle  Triangle shaped craft with three red lights at...
# 6        light  Three red lights over southern California that...
# 7        light  3 Red lights in line pattern above El Cajon/ E...
# 8      unknown                One huge UFO or three seperate ones
# 9        light                           Lights orbiting the moon
# 10    fireball  7 floating orbs or fireballs moving from south...
# 11   formation  Three red lights over the San Diego area - IT&...
# 12       light  Three bright red lights in a straight line for...
# 13   formation  four orange red objects suddenly appear 12:01 ...
# 14       other  Objects in sky over Antioch California 12:03AM...
# 15       light                 3 red lights in sky new years 2010
# 16      sphere  i&#39m in naples park. last night&#44 my husba...
# 17    triangle  3 bright red lights hovering high in the sky i...
# 18       light  Upper atmosphere object moving south&#44 becom...
# 19   formation  3 red lights over the mountains in Eastern San...
# 20    fireball  Slow moving fireball northbound at hight altit...
# 21        disk  We experienced red disk over the falcon&#44 co...
# 22     unknown  Orange/Yellow flickering light in the sky with...
# 23     chevron            New Years Eve Anomoly In Aspen Colorado
# 24      sphere  Large red/orange orb traveling southeast betwe...
# 25     unknown            Six flickering orange lights over baker
# 26      sphere  Orange spheres in sky New Year&#39s Eve&#44 Sa...
# 27      sphere  4 redishorange shpereiodical objects appear du...
# 28    triangle                       It happen nEw years eve 2010
# 29    triangle   Haverhill Massachusetts triangle object sighting
# ..         ...                                                ...
# 796      cigar  Sighting on Vanderbilt Beach&#44 Naples&#44 Fl...
# 797       disk  A large&#44saucer shaped object&#44that i did ...
# 798    unknown                      UFO shot down over Civilians?
# 799     circle       six orange lights fly over Santa Cruz&#44 CA
# 800      light  Unusual stationary&#44 elongated and bright li...
# 801   triangle  It was like a large glass like structure with ...
# 802     circle                          UFO over Sandia Mountains
# 803      flash     Multicolored UFO seen over Edson Alberta Twice
# 804       disk  I saw a big tilted dark gray saucer-like objec...
# 805     circle  saw round gold ball withgray gue coming out sl...
# 806       disk                            Silver disk over Oregon
# 807      light  I saw a glowing&#44 red object fly through the...
# 808     circle  Blue dotted lights forming a circle. Bright wh...
# 809    unknown  Amber lights seen in night sky in Austin&#44 T...
# 810      light  three lights over Fort Atkinson&#44 Wisconsin ...
# 811    diamond  Diamond shaped object with lights hovering the...
# 812       oval  Orb like object flying low  over wilmington ca...
# 813    unknown  bright silver gray color fish shaped object. V...
# 814   triangle  Three red light in the shape of a triangle mov...
# 815      other  I saw giant birds flying at very fast speeds i...
# 816       disk  ((HOAX??))  I thought they were birds but the ...
# 817   changing  Bright objects and flashes over Louisville&#44...
# 818    diamond  Walking on the South campus of the University ...
# 819    unknown  I just witnessed a large static formation or 1...
# 820      light          Small lights that fly around in formation
# 821      light  Around 12 red lights moving in loose formation...
# 822      light  Circular objects with very bright hallow ((sic...
# 823    unknown       3 unknown objects in the skies of west Texas
# 824  formation  It was around 9:20pm last night (May 4&#44 201...
# 825      light  Two bright flashes lighting up the entire sky ...
#
# [826 rows x 7 columns]

# %%
df.to_html('conv_Table.html')
